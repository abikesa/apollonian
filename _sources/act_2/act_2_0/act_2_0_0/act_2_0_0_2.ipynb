# %% [markdown]
# #
#
# # 14
#
# $
# \Large
# \left\{
# \begin{array}{ll}
# \text{Truth} \\
# \text{} \\
# \textcolor{gray}{\text{Knowledge}} \ \
# \left\{ \begin{array}{l} \textcolor{gray}{\text{Rigor}} \text{} \\ \text{Error} \ \ \ \ \ \ \ \ \
# \left\{ \begin{array}{l} \text{Variance} \\ \text{Bias}  \end{array} \right. \\ \text{Sloppy}  \end{array} \right.
# \left\{ \begin{array}{l} \text{Explain/Control} \end{array}  \right. \\
# \text{} \\
# \text{Justice}
# \end{array}
# \right.
# $

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.cm import ScalarMappable
from matplotlib.colors import LinearSegmentedColormap, PowerNorm

def gaussian(x, mean, std_dev, amplitude=1):
    return amplitude * np.exp(-0.9 * ((x - mean) / std_dev) ** 2)

def overlay_gaussian_on_line(ax, start, end, std_dev):
    x_line = np.linspace(start[0], end[0], 100)
    y_line = np.linspace(start[1], end[1], 100)
    mean = np.mean(x_line)
    y = gaussian(x_line, mean, std_dev, amplitude=std_dev)
    ax.plot(x_line + y / np.sqrt(2), y_line + y / np.sqrt(2), color='red', linewidth=2.5)

fig, ax = plt.subplots(figsize=(10, 10))

intervals = np.linspace(0, 100, 11)
custom_means = np.linspace(1, 23, 10)
custom_stds = np.linspace(.5, 10, 10)

# Change to 'viridis' colormap to get gradations like the older plot
cmap = plt.get_cmap('viridis')
norm = plt.Normalize(custom_stds.min(), custom_stds.max())
sm = ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

median_points = []

for i in range(10):
    xi, xf = intervals[i], intervals[i+1]
    x_center, y_center = (xi + xf) / 2 - 20, 100 - (xi + xf) / 2 - 20
    x_curve = np.linspace(custom_means[i] - 3 * custom_stds[i], custom_means[i] + 3 * custom_stds[i], 200)
    y_curve = gaussian(x_curve, custom_means[i], custom_stds[i], amplitude=15)
    
    x_gauss = x_center + x_curve / np.sqrt(2)
    y_gauss = y_center + y_curve / np.sqrt(2) + x_curve / np.sqrt(2)
    
    ax.plot(x_gauss, y_gauss, color=cmap(norm(custom_stds[i])), linewidth=2.5)
    median_points.append((x_center + custom_means[i] / np.sqrt(2), y_center + custom_means[i] / np.sqrt(2)))

median_points = np.array(median_points)
ax.plot(median_points[:, 0], median_points[:, 1], '--', color='grey')
start_point = median_points[0, :]
end_point = median_points[-1, :]
overlay_gaussian_on_line(ax, start_point, end_point, 24)

ax.grid(True, linestyle='--', linewidth=0.5, color='grey')
ax.set_xlim(-30, 111)
ax.set_ylim(-20, 87)

# Create a new ScalarMappable with a reversed colormap just for the colorbar
cmap_reversed = plt.get_cmap('viridis').reversed()
sm_reversed = ScalarMappable(cmap=cmap_reversed, norm=norm)
sm_reversed.set_array([])

# Existing code for creating the colorbar
cbar = fig.colorbar(sm_reversed, ax=ax, shrink=1, aspect=90)

# Specify the tick positions you want to set
custom_tick_positions = [0.5, 5, 8, 10]  # example positions, you can change these
cbar.set_ticks(custom_tick_positions)

# Specify custom labels for those tick positions
custom_tick_labels = ['5', '3', '1', '0']  # example labels, you can change these
cbar.set_ticklabels(custom_tick_labels)

# Label for the colorbar
cbar.set_label(r'♭', rotation=0, labelpad=15, fontstyle='italic', fontsize=24)


# Label for the colorbar
cbar.set_label(r'♭', rotation=0, labelpad=15, fontstyle='italic', fontsize=24)


cbar.set_label(r'♭', rotation=0, labelpad=15, fontstyle='italic', fontsize=24)

# Add X and Y axis labels with custom font styles
ax.set_xlabel(r'Mode', fontstyle='italic')
ax.set_ylabel(r'Mood', rotation=0, fontstyle='italic', labelpad=15)

# Add musical modes as X-axis tick labels
musical_modes = ["Ionian", "Dorian", "Phrygian", "Lydian", "Mixolydian", "Aeolian", "Locrian"]
mode_positions = np.linspace(ax.get_xlim()[0], ax.get_xlim()[1], len(musical_modes))
ax.set_xticks(mode_positions)
ax.set_xticklabels(musical_modes, rotation=45)

# Add moods as Y-axis tick labels
moods = ["flow", "control", "relaxation", "bored", "apathy", "worry", "anxiety", "arousal"]
mood_positions = np.linspace(ax.get_ylim()[0], ax.get_ylim()[1], len(moods))
ax.set_yticks(mood_positions)
ax.set_yticklabels(moods)

# ... (rest of the code unchanged)


plt.tight_layout()
plt.show()

# %% [markdown]
# To clarify. Women have wanted all this stuff from the beginning of time: to be accepted as they are and “spoiled” or treated like a Queen.
#
# So it’s just the level of assertion of their needs that has increased with time.
#
# Bwana Odinga’s notes are just a man’s diary or journal, a depiction of the evolution of his understanding.
#
# In grammar, philosophy, and algebra, we can say that the underlying subject, the ontology, the women, are a constant. But our understanding, from our interacting with them, the epistemology, is improving and is the real variable.
#
# Suppose the truth were a woman, what then?? That’s how Nietzsche starts his beautiful book “[Beyond Good and Evil](https://www.gutenberg.org/files/4363/4363-h/4363-h.htm)”
#
# All things are subject to interpretation. Whichever interpretation prevails at a given time is a function of power and not truth. So women now have more power than ever. And they get it from their jobs and DMs
#
# <Details>
#    <Summary></Summary>
#
# The quote "All things are subject to interpretation. Whichever interpretation prevails at a given time is a function of power and not truth" is often attributed to Friedrich Nietzsche, a 19th-century German philosopher. Nietzsche was interested in challenging conventional beliefs and questioning the origins and bases of societal norms, ethics, and knowledge. His work frequently delved into the ways in which power dynamics affect human interactions, including the interpretation of "truth."
#
# In essence, the quote suggests that our understanding of any situation, concept, or phenomenon is not simply a matter of objective fact but is shaped by the frameworks and perspectives we employ, which are in turn influenced by `power structures`. What is considered to be "true" can often be what those in power decide is true, rather than what is empirically or morally accurate.
#
# This perspective aligns with the discussions on truth, knowledge, and morality in your research framework. Power dynamics can serve as a source of bias, affecting what is considered to be rigorous or valid in academic and practical contexts. It is essential to be aware of these influences, especially when analyzing data or constructing models that aim to explain variance and control bias.
# Sils Maria Upper Engadine, JUNE, 1885.
#
# </Details>
#
# <Details>
#    <Summary></Summary>
#
# <span style="font-size:23px;font-weight:bold;">Key Themes</span>:
# 1. **The Nature of Truth**: Nietzsche suggests that the concept of truth is not as objective as traditional philosophers make it out to be. He challenges dogmatism, asserting that the very constructs of "Pure Spirit" and the "Good in Itself" are problematic.
#
# 2. **Power and Interpretation**: The idea that truth is often dictated by those in power. Women, gaining power in various spheres like the workforce, are now more influential in shaping their narrative.
#
# 3. **The Ontology-Epistemology Dichotomy**: In the case of understanding women, or any subject, the entity itself might be constant, but our understanding (epistemology) is ever-changing. In essence, our interaction shapes our understanding, making epistemology the real variable.
#
# 4. **Cultural Evolution**: An evolutionary shift is seen in terms of power dynamics and the understanding of subjects like women, truth, and morality. This change can be noted in various elements, such as Bwana Odinga’s evolving perspectives recorded in his diary.
#
# <span style="font-size:23px;font-weight:bold;">Hierarchical Understanding of Knowledge</span><br>
# - **Truth**: The top-most element, subject to change and interpretation.
#   - **Knowledge**: Various types of knowledge like rigor and error feed into the truth.
#     - **Error**: Categorized into variance and bias.
#       - **Variance & Bias**: Need to be explained and controlled to approach truth.
# - **Force**: Which ultimately brings us back to the data-generating process
#   - **Power**: Silos of power are distributed geographically and socially
#   - **Hierarchy**: Everything is to be understood in the context of hierarchies of power
#     - Dionysian force, cosmic and biological in nature, is highest
#     - Apollonian silos, moreorless social, are defined and reinforced by those in power
#     - Birth of trajedy, a notion of remaining superficial out of profundity, like the ancient Greeks
#
# <span style="font-size:23px;font-weight:bold;">Intersections with Nietzsche</span><br>
# - Power dynamics play a role in what is considered rigorous or valid, paralleling Nietzsche's perspectives on truth being influenced by power.
#
# <span style="font-size:23px;font-weight:bold;">Current Events</span><br>
# - Google Cloud Next ’24 announced for April 9-11, 2024, at Mandalay Bay, Convention Center, Las Vegas, NV.
#
# <span style="font-size:23px;font-weight:bold;">Quote for Reflection</span><br>
# "Supposing that Truth is a woman—what then? Is there not ground for suspecting that all philosophers, in so far as they have been dogmatists, have failed to understand women?" - Nietzsche in "Beyond Good and Evil."
# </Details>
#
# <Details>
#    <Summary></Summary>
#
# <h3>Summary:</h3>
#
# <p>The conversation delves into the complex interplay between truth, knowledge, and power, drawing from Nietzsche's philosophy as well as the evolving perspectives recorded in Bwana Odinga&rsquo;s diary.</p>
#
# <ol>
#   <li><b>Truth and Power</b>: Nietzsche argues that truth is not an objective constant but is shaped by power dynamics. This is illustrated by the rising influence of women, who are increasingly empowered to assert themselves in various spheres like the workforce and social media (DMs).</li>
#
#   <li><b>Ontology-Epistemology Dichotomy</b>: While the underlying subject (e.g., women) may remain constant, our understanding of them is fluid and changes with time and interaction. This makes epistemology—the study of knowledge—the real variable.</li>
#
#   <li><b>Error and Bias</b>: Within the realm of knowledge, 'error' is bifurcated into 'variance' and 'bias'. Both need to be explained and controlled to arrive at a more accurate understanding of truth.</li>
#
#   <li><b>Cultural Evolution</b>: Bwana Odinga&rsquo;s diary symbolizes the changing landscape of understanding subjects like women, truth, and morality over time.</li>
#
#   <li><b>Hierarchical Understanding</b>: Knowledge, errors, and their sub-categories are nested in a hierarchical structure. This hierarchical understanding can be cosmically, biologically, and socially contextualized.</li>
#
#   <li><b>Ending Notes</b>: The discussion concludes with the idea that our search for truth is constrained by our methods and perspectives, requiring a return to data-generating processes to clarify bias and variance. Thus, the quest for truth is continuous and complex, influenced by the play of power and interpretation in the society.</li>
# </ol>
#
# </Details>
#
#
# <Details>
#    <Summary></Summary>
#
# Pablo Larraín was born on August 19, 1976, in Santiago, Chile. He is part of the Larraín family, a prominent family in Chile with a history of involvement in politics and business. His father, Hernán Larraín, is a Chilean lawyer, academic, and politician. Despite his well-off background, Larraín's films often explore the socio-political complexities of Chilean history, with a particular focus on the country's tumultuous past.
#
# As for his education, he studied audiovisual communication at the University of Arts, Sciences, and Communication in Santiago. He did not pursue formal film school training, but his works have garnered significant international recognition, showing a deep understanding of both film aesthetics and political context.
#
# Regarding his real-life stance, Larraín appears to be deeply committed to exploring the nuances and complexities of Chile's social and political landscape. He has spoken openly about the legacies of violence, politics, and economic models in shaping Chilean society. While he may not categorize himself within any specific school of thought, his works certainly engage with themes of societal and political importance. For instance, his film "No" scrutinizes the role of media and public perception in the context of a historical political event.
#
# In the broader context of Latin American film and literature, the concept of magical realism and Harold Bloom's "School of Resentment" offer interesting lenses through which to view Larraín's work. While Larraín's films are not usually classified as magical realism, they do tackle similar themes of history, oppression, and identity, much like the genre does. And although his films are deeply political, they are `also recognized for their artistic merit, thus evading the risk of reduction to mere social critique that Bloom laments`.
#
# Given your interest in interdisciplinary themes and how tokens/fetters influence creativity and understanding, Larraín's films could provide an interesting case study. They delve into the societal 'tokens' and 'fetters' that shape Chilean history while also offering an aesthetic experience that defies straightforward categorization.
#
# - So the lamentation is with regard to navel-gazers in the Apollonian silos they've failed to emerge from
# - A Dionysian perspective an all-encompassing, shearing force, like the red gaussian curve depicted
# - That is the multi-perspectivity Nietzsche extols as the only "truth", which Einstein inadvatently agrees to
# - Navel-gazers have a provincial view of things and a notion of "truth" that is mere symptom of their psychology
#
# > *Out of the spirit of music we encounter the most evocative and pleasing music as intermodel*
#
# - Perhaps this is also the very essence of humor: lightening folks with legitimate reasons for misery
#
# </Details>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <Details>
# <Summary></Summary>
#
# Announcing Google Cloud Next ’24<br>
# April 9-11, 2024<br>
# <span style="color:grey;">Mandalay Bay, Convention Center, Las Vegas, NV</span><br>
# </Details>
